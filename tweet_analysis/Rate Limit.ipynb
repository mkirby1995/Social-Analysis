# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from decouple import config
import tweepy
import basilica

import matplotlib
import matplotlib.cbook as cb
from matplotlib.colors import colorConverter, Colormap
from matplotlib.collections import LineCollection
import numpy
import networkx.drawing
from networkx.drawing import nx_pylab

#Import Keys
TWITTER_AUTH = tweepy.OAuthHandler(
    config('TWITTER_CONSUMER_KEY'),
    config('TWITTER_CONSUMER_SECRET'))
TWITTER_AUTH.set_access_token(
    config('TWITTER_ACCESS_TOKEN'),
    config('TWITTER_ACCESS_TOKEN_SECRET'))
TWITTER = tweepy.API(TWITTER_AUTH)
BASILICA = basilica.Connection(config('BASILICA_KEY'))

# %%
TWITTER.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '219574192-Dw9dsBrkLwa36OCF1yoLdGalT4nD2w0ByGHKB762'},
#  'resources': {'lists': {'/lists/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1584990267},
#    '/lists/subscribers/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1584990267},
#    '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1584990267},
#    '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1584990267},
#    '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1584990267}},
#   'application': {'/application/rate_limit_status': {'limit': 180,
#     'remaining': 179,
#     'reset': 1584990267}},
#   'mutes': {'/mutes/users/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/mutes/users/ids': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267}},
#   'friendships': {'/friendships/outgoing': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1584990267},
#    '/friendships/no_retweets/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/friendships/incoming': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1584990267}},
#   'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1584990267},
#    '/guide/get_explore_locations': {'limit': 100,
#     'remaining': 100,
#     'reset': 1584990267},
#    '/guide/explore_locations_with_autocomplete': {'limit': 200,
#     'remaining': 200,
#     'reset': 1584990267}},
#   'auth': {'/auth/csrf_token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'blocks': {'/blocks/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'geo': {'/geo/similar_places': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1584990267},
#    '/geo/id/:place_id': {'limit': 75, 'remaining': 75, 'reset': 1584990267},
#    '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'users': {'/users/report_spam': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/users/contributors/pending': {'limit': 2000,
#     'remaining': 2000,
#     'reset': 1584990267},
#    '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1584990267},
#    '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1584990267},
#    '/users/suggestions/:slug': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/users/contributees/pending': {'limit': 200,
#     'remaining': 200,
#     'reset': 1584990267},
#    '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/users/profile_banner': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/users/suggestions/:slug/members': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1584990267},
#    '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'teams': {'/teams/authorize': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'followers': {'/followers/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'collections': {'/collections/list': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267},
#    '/collections/entries': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267},
#    '/collections/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267}},
#   'statuses': {'/statuses/retweeters/ids': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/statuses/retweets_of_me': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/statuses/home_timeline': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1584990267},
#    '/statuses/user_timeline': {'limit': 900,
#     'remaining': 900,
#     'reset': 1584990267},
#    '/statuses/friends': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/statuses/retweets/:id': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/statuses/mentions_timeline': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1584990267},
#    '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1584990267}},
#   'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/custom_profiles/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267}},
#   'webhooks': {'/webhooks/subscriptions/direct_messages': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'contacts': {'/contacts/uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1584990267},
#    '/contacts/addressbook': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/contacts/users_and_uploaded_by': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/contacts/delete/status': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267}},
#   'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#     'remaining': 5,
#     'reset': 1584990267},
#    '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#     'remaining': 10,
#     'reset': 1584990267},
#    '/labs/:version/tweets/stream/filter/': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1584990267},
#    '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/labs/:version/tweets/stream/sample': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/labs/:version/tweets/metrics/private': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/labs/:version/tweets/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1584990267},
#    '/labs/:version/users/*': {'limit': 900,
#     'remaining': 900,
#     'reset': 1584990267},
#    '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/labs/:version/tweets/search': {'limit': 225,
#     'remaining': 225,
#     'reset': 1584990267}},
#   'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/tweet_prompts/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267}},
#   'moments': {'/moments/statuses/update': {'limit': 5,
#     'remaining': 5,
#     'reset': 1584990267},
#    '/moments/permissions': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267}},
#   'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#     'remaining': 4500,
#     'reset': 1584990267}},
#   'fleets': {'/fleets/:version/delete': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/fleets/:version/create': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/fleets/:version/user_fleets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/fleets/:version/home_timeline': {'limit': 100,
#     'remaining': 100,
#     'reset': 1584990267},
#    '/fleets/:version/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267}},
#   'help': {'/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/help/configuration': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'feedback': {'/feedback/show/:id': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/feedback/events': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267}},
#   'business_experience': {'/business_experience/dashboard_settings/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/business_experience/dashboard_features': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/business_experience/keywords': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/business_experience/dashboard_settings/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/business_experience/dashboard_settings/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267}},
#   'graphql&POST': {'/graphql&POST': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'friends': {'/friends/following/ids': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/friends/following/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1584990267},
#    '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267}},
#   'drafts': {'/drafts/statuses/update': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/drafts/statuses/destroy': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/drafts/statuses/ids': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/drafts/statuses/list': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/drafts/statuses/show': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/drafts/statuses/create': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267}},
#   'direct_messages': {'/direct_messages/sent': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/direct_messages/broadcasts/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1584990267},
#    '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267},
#    '/direct_messages/mark_read': {'limit': 1000,
#     'remaining': 1000,
#     'reset': 1584990267},
#    '/direct_messages/subscribers/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/direct_messages/sent_and_received': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#     'remaining': 60,
#     'reset': 1584990267},
#    '/direct_messages': {'limit': 300, 'remaining': 300, 'reset': 1584990267},
#    '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/direct_messages/subscribers/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/direct_messages/broadcasts/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1584990267},
#    '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#     'remaining': 60,
#     'reset': 1584990267},
#    '/direct_messages/subscribers/lists/list': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/direct_messages/show': {'limit': 300,
#     'remaining': 300,
#     'reset': 1584990267},
#    '/direct_messages/events/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/direct_messages/subscribers/lists/show': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267},
#    '/direct_messages/events/show': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'media': {'/media/upload': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267}},
#   'traffic': {'/traffic/map': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'account_activity': {'/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267},
#    '/account_activity/direct_messages/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267},
#    '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267},
#    '/account_activity/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#     'remaining': 500,
#     'reset': 1584990267},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/account/authenticate_web_view': {'limit': 50,
#     'remaining': 50,
#     'reset': 1584990267},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'safety': {'/safety/detection_feedback': {'limit': 450000,
#     'remaining': 450000,
#     'reset': 1584990267}},
#   'favorites': {'/favorites/list': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267}},
#   'device': {'/device/token': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'tweets': {'/tweets/search/:product/:label': {'limit': 1800,
#     'remaining': 1800,
#     'reset': 1584990267},
#    '/tweets/search/:product/:instance/counts': {'limit': 900,
#     'remaining': 900,
#     'reset': 1584990267}},
#   'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/saved_searches/show/:id': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/saved_searches/list': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}},
#   'oauth': {'/oauth/revoke': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267},
#    '/oauth/invalidate_token': {'limit': 450,
#     'remaining': 450,
#     'reset': 1584990267},
#    '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1584990267}},
#   'search': {'/search/tweets': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267}},
#   'trends': {'/trends/closest': {'limit': 75,
#     'remaining': 75,
#     'reset': 1584990267},
#    '/trends/available': {'limit': 75, 'remaining': 75, 'reset': 1584990267},
#    '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1584990267}},
#   'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#     'remaining': 180,
#     'reset': 1584990267}},
#   'graphql': {'/graphql': {'limit': 15,
#     'remaining': 15,
#     'reset': 1584990267}}}}
